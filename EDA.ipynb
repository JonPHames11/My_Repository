# %%
import pandas as pd
import numpy as np
import scipy as st
import matplotlib.pyplot as plt
import plotly.express as px
import nbformat as nbf

print("All Good")
# Out:
# All Good

# %%
vehicles_us = pd.read_csv(r'C:\Users\lefty\My_Repository\vehicles_us.csv')

print(vehicles_us.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
# None

# %%
vehicles_us['model_year'] = vehicles_us['model_year'].round().astype('Int64')
print(vehicles_us.head(10))
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good        6.0  gas  145000.0
# 1  25500        <NA>      ford f-150       good        6.0  gas   88705.0
# 2   5500        2013  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500        2003      ford f-150       fair        8.0  gas       NaN
# 4  14900        2017    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990        2014    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990        2015    toyota camry  excellent        4.0  gas   79212.0
# 7  15990        2013     honda pilot  excellent        6.0  gas  109473.0
# 8  11500        2012     kia sorento  excellent        4.0  gas  104174.0
# 9   9200        2008     honda pilot  excellent        NaN  gas  147191.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# ...

# %%
print(vehicles_us.isna().sum())
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
vehicles_us['model_year'] = vehicles_us['model_year'].fillna(
    vehicles_us.groupby('model')['model_year'].median())
vehicles_us['cylinders'] = pd.to_numeric(vehicles_us['cylinders'], errors='coerce').fillna(0).astype(int)
vehicles_us['odometer'] = pd.to_numeric(vehicles_us['odometer'], errors='coerce').fillna(0).astype(int)
vehicles_us['paint_color'] = vehicles_us['paint_color'].fillna('Unknown')
vehicles_us['is_4wd'] = vehicles_us['is_4wd'].fillna(0).astype(int)
print(vehicles_us.isna().sum())
print()
print(vehicles_us.head(10))
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64
#
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500           0      ford f-150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003      ford f-150       fair          8  gas         0
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
# 5  14990        2014    chrysler 300  excellent          6  gas     57954
# 6  12990        2015    toyota camry  excellent          4  gas     79212
# 7  15990        2013     honda pilot  excellent          6  gas    109473
# ...

# %%
vehicles_us['model_year'] =
# Out:
# price               0
# model_year      51525
# model               0
# condition           0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# type                0
# paint_color         0
# is_4wd              0
# date_posted         0
# days_listed         0
# dtype: int64
#
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400         NaN          bmw x5       good          6  gas    145000
# 1  25500         NaN      ford f-150       good          6  gas     88705
# 2   5500         NaN  hyundai sonata   like new          4  gas    110000
# 3   1500         NaN      ford f-150       fair          8  gas         0
# 4  14900         NaN    chrysler 200  excellent          4  gas     80903
# 5  14990         NaN    chrysler 300  excellent          6  gas     57954
# 6  12990         NaN    toyota camry  excellent          4  gas     79212
# ...

# %%
import plotly.express as px

vehicles_us_copy = vehicles_us.copy()

# Calculate average price per model
avg_price = vehicles_us_copy.groupby('model')['price'].mean().round(2).reset_index()

# Sort by average price and select top 10
avg_price_top10 = avg_price.sort_values(by='price', ascending=False).head(10)

# Plot the bar chart
fig = px.bar(
    avg_price_top10,
    x='model',
    y='price',
    color='model',
    title='Top 10 Models by Average Price',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()

# %%
import plotly.express as px

vehicles_us_copy = vehicles_us.copy()

# Group by 'type' and count how many vehicles per type
count_by_type = vehicles_us_copy['type'].value_counts().reset_index()
count_by_type.columns = ['type', 'count']

# Sort for better display
count_by_type = count_by_type.sort_values(by='count', ascending=False)

# Plot the bar chart
fig = px.bar(
    count_by_type,
    x='type',
    y='count',
    color='type',
    title='Count of Vehicles by Type',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
